# %% [markdown]
# <a href="https://colab.research.google.com/github/nouran551/satellite-orbit-shape-parameters/blob/master/Relationship_between_satalitte_orbit_Shape_Parameters_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://www.spaceacademy.net.au/watch/track/satellip.gif)
#
# The above image represents a satellite in an elliptical orbit around the Earth. The long or major axis of the ellipse is the length AP and the short or minor axis of the ellipse is the length m1-m2. The ellipse can be specified by two quantities, the semi-major axis a and the semi-minor axis b. The two points f1 and f2 are called the foci (plural of focus) of the ellipse, and the Earth is always at one focus of the ellipse, in this case f1. The distance of the foci to the centre of the ellipse is c, and c2 = a2 - b2.
#
# The shape of the ellipse is defined by the relative values of a and b and is specified by another quantity e, the eccentricity of the ellipse, where
#
# e2 = 1 - ( b / a )2
# When b=a the eccentricity is zero and ellipse becomes a circle. The eccentricity can have have values from o up to nearly 1. At a value of e=1 the geometry becomes a parabola, which is no longer an ellipse. When this occurs the satellite would no longer be in orbit around the planet. Values of e close to 1 result in a very elongated orbit.
# The point P is called the perigee of the orbit and this is where the satellite is at its closest point to the Earth. The point A is called the apogee and this is where the satellite is at its furthest distance from the planet. Perigee and apogee distances can be calculated using :
#
# q = a ( 1 + e ) ... apogee
#
#
# p = a ( 1 - e ) ... perigee

# %%
import numpy as np

semimajor_axis = 10000  #Changable
Eccentricity = 0.1      #Changable 0 ~ 1

c = semimajor_axis * Eccentricity

semiminor_axis = np.sqrt(pow(semimajor_axis,2) - pow(c,2))

perigee = semimajor_axis * (1-Eccentricity)
apogee = semimajor_axis * (1+Eccentricity)

print("The orbit's semi-minor axis is",semiminor_axis,"Km")
# Out:
# The orbit's semi-minor axis is 9949.8743710662 Km

# %%
if Eccentricity == 0 :
  print ('The orbit is circular')

else :
  print('The Foci Points are', c ,"Km far from the center of the orbit and the Earth can be at anyone of them")


print('The perigee radius is', perigee,'Km')
print('The altitude of the Perigee is ', perigee - 6471 ,'Km')
print('The Apogee radius is', apogee,'Km')
print('The altitude of the Apogee is', apogee - 6371 ,'Km')
# Out:
# The Foci Points are 1000.0 Km far from the center of the orbit and the Earth can be at anyone of them
# The perigee radius is 9000.0 Km
# The altitude of the Perigee is  2529.0 Km
# The Apogee radius is 11000.0 Km
# The altitude of the Apogee is 4629.0 Km

# %% [markdown]
# **Relation between the Semi-minor axis and the Eccentricity with constant Semi-major.**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


labels = 'Eccentricity', 'semiminor_axis','semiminor_axix' ,'perigee', 'apogee'
sizes = [Eccentricity, semimajor_axis,semiminor_axis, perigee, apogee]
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
objects = ('Eccentricity', 'semiminor_axis','semiminor_axix' ,'perigee', 'apogee')
y_pos = np.arange(len(objects))
performance = [Eccentricity, semimajor_axis,semiminor_axis, perigee, apogee]

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('Length in Km')
plt.title('satellite orbit shape parameters')

plt.show()

# %%
plt.plot([Eccentricity, semimajor_axis,semiminor_axis, perigee, apogee])
plt.ylabel('satellite orbit shape parameters')
plt.show()

# %% [markdown]
# Another Relation between the Semi-minor axis and the Eccentricity with constant Semi-
# major. When the Eccentricity is equal to zero the orbit is circular and the Perigee and Apogee
# are equal

# %%
import numpy as np

semimajor_axis = 10000  #Changable
Eccentricity = 0      #Changable 0 ~ 1

c = semimajor_axis * Eccentricity

semiminor_axis = np.sqrt(pow(semimajor_axis,2) - pow(c,2))

perigee = semimajor_axis * (1-Eccentricity)
apogee = semimajor_axis * (1+Eccentricity)

print("The orbit's semi-minor axis is",semiminor_axis,"Km")
# Out:
# The orbit's semi-minor axis is 10000.0 Km

# %%
if Eccentricity == 0 :
  print ('The orbit is circular')

else :
  print('The Foci Points are', c ,"Km far from the center of the orbit and the Earth can be at anyone of them")


print('The perigee radius is', perigee,'Km')
print('The altitude of the Perigee is ', perigee - 6471 ,'Km')
print('The Apogee radius is', apogee,'Km')
print('The altitude of the Apogee is', apogee - 6371 ,'Km')
# Out:
# The orbit is circular
# The perigee radius is 10000 Km
# The altitude of the Perigee is  3529 Km
# The Apogee radius is 10000 Km
# The altitude of the Apogee is 3629 Km

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


labels = 'Eccentricity', 'semiminor_axis','semiminor_axix' ,'perigee', 'apogee'
sizes = [Eccentricity, semimajor_axis,semiminor_axis, perigee, apogee]
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
objects = ('Eccentricity', 'semiminor_axis','semiminor_axix' ,'perigee', 'apogee')
y_pos = np.arange(len(objects))
performance = [Eccentricity, semimajor_axis,semiminor_axis, perigee, apogee]

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('Length in Km')
plt.title('satellite orbit shape parameters')

plt.show()

# %%
plt.plot([Eccentricity, semimajor_axis,semiminor_axis, perigee, apogee])
plt.ylabel('satellite orbit shape parameters')
plt.show()

# %% [markdown]
# Relation between the Semi-major axis and the Semi-minor
# axis with a constant Eccentricity.
# **bold text**

# %%
import numpy as np

semimajor_axis = 15000  #Changable
Eccentricity = 0.5      #Changable 0 ~ 1

c = semimajor_axis * Eccentricity

semiminor_axis = np.sqrt(pow(semimajor_axis,2) - pow(c,2))

perigee = semimajor_axis * (1-Eccentricity)
apogee = semimajor_axis * (1+Eccentricity)

print("The orbit's semi-minor axis is",semiminor_axis,"Km")
# Out:
# The orbit's semi-minor axis is 12990.38105676658 Km

# %%
if Eccentricity == 0 :
  print ('The orbit is circular')

else :
  print('The Foci Points are', c ,"Km far from the center of the orbit and the Earth can be at anyone of them")


print('The perigee radius is', perigee,'Km')
print('The altitude of the Perigee is ', perigee - 6471 ,'Km')
print('The Apogee radius is', apogee,'Km')
print('The altitude of the Apogee is', apogee - 6371 ,'Km')
# Out:
# The Foci Points are 7500.0 Km far from the center of the orbit and the Earth can be at anyone of them
# The perigee radius is 7500.0 Km
# The altitude of the Perigee is  1029.0 Km
# The Apogee radius is 22500.0 Km
# The altitude of the Apogee is 16129.0 Km

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


labels = 'Eccentricity', 'semiminor_axis','semiminor_axix' ,'perigee', 'apogee'
sizes = [Eccentricity, semimajor_axis,semiminor_axis, perigee, apogee]
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
objects = ('Eccentricity', 'semiminor_axis','semiminor_axix' ,'perigee', 'apogee')
y_pos = np.arange(len(objects))
performance = [Eccentricity, semimajor_axis,semiminor_axis, perigee, apogee]

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('Length in Km')
plt.title('satellite orbit shape parameters')

plt.show()

# %%
plt.plot([Eccentricity, semimajor_axis,semiminor_axis, perigee, apogee])
plt.ylabel('satellite orbit shape parameters')
plt.show()

# %% [markdown]
# Another relation between the Semi-major axis and the Semi-minor axis with a constant
# Eccentricity.

# %%
import numpy as np

semimajor_axis = 9000  #Changable
Eccentricity = 0.5      #Changable 0 ~ 1

c = semimajor_axis * Eccentricity

semiminor_axis = np.sqrt(pow(semimajor_axis,2) - pow(c,2))

perigee = semimajor_axis * (1-Eccentricity)
apogee = semimajor_axis * (1+Eccentricity)

print("The orbit's semi-minor axis is",semiminor_axis,"Km")
# Out:
# The orbit's semi-minor axis is 7794.228634059948 Km

# %%
if Eccentricity == 0 :
  print ('The orbit is circular')

else :
  print('The Foci Points are', c ,"Km far from the center of the orbit and the Earth can be at anyone of them")


print('The perigee radius is', perigee,'Km')
print('The altitude of the Perigee is ', perigee - 6471 ,'Km')
print('The Apogee radius is', apogee,'Km')
print('The altitude of the Apogee is', apogee - 6371 ,'Km')
# Out:
# The Foci Points are 4500.0 Km far from the center of the orbit and the Earth can be at anyone of them
# The perigee radius is 4500.0 Km
# The altitude of the Perigee is  -1971.0 Km
# The Apogee radius is 13500.0 Km
# The altitude of the Apogee is 7129.0 Km

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


labels = 'Eccentricity', 'semiminor_axis','semiminor_axix' ,'perigee', 'apogee'
sizes = [Eccentricity, semimajor_axis,semiminor_axis, perigee, apogee]
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
objects = ('Eccentricity', 'semiminor_axis','semiminor_axix' ,'perigee', 'apogee')
y_pos = np.arange(len(objects))
performance = [Eccentricity, semimajor_axis,semiminor_axis, perigee, apogee]

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('Length in Km')
plt.title('satellite orbit shape parameters')

plt.show()

# %%
plt.plot([Eccentricity, semimajor_axis,semiminor_axis, perigee, apogee])
plt.ylabel('satellite orbit shape parameters')
plt.show()
